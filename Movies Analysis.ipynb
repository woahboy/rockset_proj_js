# %%
from rockset import Client, ParamDict
import sys
import re
import pprint
import matplotlib.pyplot as plt
import os

# %%
cal_year = 2001
rs_api_key = os.environ['API_KEY']

# %%
rs = Client(api_key=rs_api_key,
          api_server='https://api.use1a1.rockset.com')
pp = pprint.PrettyPrinter(indent=0,width=240)

# %%
# retrieve Most Popular Movies
qlambda = rs.QueryLambda.retrieveByTag(
    '1_most_popular_movies_v1',
    tag='latest',
    workspace='commons')

params = ParamDict()
params['cal_year'] = cal_year
results = qlambda.execute(parameters=params)
print(" ")
print("Most Popular Movies in " + str(cal_year))
pp.pprint(results["results"])
print(" ")
# Out:
#
# Most Popular Movies in 2001
# [{'popularity': 41.048867, 'rank': 1, 'title': 'Spirited Away'},
# {'popularity': 38.187238, 'rank': 2, 'title': "Harry Potter and the Philosopher's Stone"},
# {'popularity': 26.419962, 'rank': 3, 'title': 'Monsters, Inc.'},
# {'popularity': 18.303148, 'rank': 4, 'title': 'Donnie Darko'},
# {'popularity': 18.186839, 'rank': 5, 'title': 'Spy Game'},
# {'popularity': 18.184056, 'rank': 6, 'title': 'Mulholland Drive'},
# {'popularity': 17.987728, 'rank': 7, 'title': 'Shrek'},
# {'popularity': 17.319836, 'rank': 8, 'title': 'Planet of the Apes'},
# {'popularity': 16.945657, 'rank': 9, 'title': 'The Mummy Returns'},
# {'popularity': 15.851722, 'rank': 10, 'title': 'Lara Croft: Tomb Raider'}]

# %%
index = 0
x=[]
y=[]
for i in results["results"]:
    x.append(results["results"][index]["title"])
    y.append(results["results"][index]["popularity"])
    index = index + 1
    
def valuelabel(x,y):
    for i in range(len(x)):
        plt.text(i,y[i],y[i], ha = 'center',
                 bbox = dict(facecolor = 'white', alpha =0.8))
        
plt.title("Most Popular Movies in " + str(cal_year))
plt.xlabel("Movie")
plt.ylabel("Popularity")
plt.xticks(rotation='vertical')
plt.bar(x,y)
plt.show()

# %%
# retrieve Highest Grossing Movies
qlambda = rs.QueryLambda.retrieveByTag(
    '2_highest_grossing_movies_v1',
    tag='latest',
    workspace='commons')

params = ParamDict()
params['cal_year'] = cal_year
results = qlambda.execute(parameters=params)
print(" ")
print("Highest Grossing Movies in " + str(cal_year))
pp.pprint(results["results"])
print(" ")
# Out:
#
# Highest Grossing Movies in 2001
# [{'% of Revenue': 14.0, 'rank': 1, 'revenue': 976475550, 'title': "Harry Potter and the Philosopher's Stone"},
# {'% of Revenue': 8.0, 'rank': 2, 'revenue': 562816256, 'title': 'Monsters, Inc.'},
# {'% of Revenue': 7.0, 'rank': 3, 'revenue': 484409218, 'title': 'Shrek'},
# {'% of Revenue': 6.0, 'rank': 4, 'revenue': 450717150, 'title': "Ocean's Eleven"},
# {'% of Revenue': 6.0, 'rank': 5, 'revenue': 433013274, 'title': 'The Mummy Returns'},
# {'% of Revenue': 5.0, 'rank': 6, 'revenue': 368780809, 'title': 'Jurassic Park III'},
# {'% of Revenue': 5.0, 'rank': 7, 'revenue': 362211740, 'title': 'Planet of the Apes'},
# {'% of Revenue': 4.0, 'rank': 8, 'revenue': 313542341, 'title': 'A Beautiful Mind'},
# {'% of Revenue': 4.0, 'rank': 9, 'revenue': 287553595, 'title': 'American Pie 2'},
# {'% of Revenue': 4.0, 'rank': 10, 'revenue': 274925095, 'title': 'Spirited Away'}]

# %%
index = 0
x=[]
y=[]
for i in results["results"]:
    x.append(results["results"][index]["title"])
    y.append(results["results"][index]["revenue"])
    index = index + 1
    
def valuelabel(x,y):
    for i in range(len(x)):
        plt.text(i,y[i],y[i], ha = 'center',
                 bbox = dict(facecolor = 'white', alpha =0.8))
        
plt.title("Highest Grossing Movies in " + str(cal_year))
plt.xlabel("Movie")
plt.ylabel("Revenue")
plt.xticks(rotation='vertical')
plt.bar(x,y)
plt.show()

# %%
# retrieve Most Popular Genre
qlambda = rs.QueryLambda.retrieveByTag(
    '3_most_popular_genres_v1',
    tag='latest',
    workspace='commons')

params = ParamDict()
params['cal_year'] = cal_year
results = qlambda.execute(parameters=params)
print(" ")
print("Most Popular Genres in " + str(cal_year))
pp.pprint(results["results"])
print(" ")
# Out:
#
# Most Popular Genres in 2001
# [{'Movie Count': 52, 'genre': 'Drama', 'rank': 1},
# {'Movie Count': 35, 'genre': 'Thriller', 'rank': 2},
# {'Movie Count': 31, 'genre': 'Comedy', 'rank': 3},
# {'Movie Count': 22, 'genre': 'Action', 'rank': 4},
# {'Movie Count': 18, 'genre': 'Romance', 'rank': 5},
# {'Movie Count': 17, 'genre': 'Crime', 'rank': 6},
# {'Movie Count': 11, 'genre': 'Science Fiction', 'rank': 7},
# {'Movie Count': 11, 'genre': 'Fantasy', 'rank': 8},
# {'Movie Count': 10, 'genre': 'Adventure', 'rank': 9},
# {'Movie Count': 10, 'genre': 'Mystery', 'rank': 10}]

# %%
index = 0
x=[]
y=[]
for i in results["results"]:
    x.append(results["results"][index]["genre"])
    y.append(results["results"][index]["Movie Count"])
    index = index + 1
    
def valuelabel(x,y):
    for i in range(len(x)):
        plt.text(i,y[i],y[i], ha = 'center',
                 bbox = dict(facecolor = 'white', alpha =0.8))
        
plt.title("Most Popular Genres in " + str(cal_year))
valuelabel(x,y)
plt.xlabel("Genre")
plt.ylabel("Movie Count")
plt.xticks(rotation='vertical')
plt.bar(x,y)
plt.show()

# %%
# retrieve Largest Producers
qlambda = rs.QueryLambda.retrieveByTag(
    '4_most_popular_genres_v1',
    tag='latest',
    workspace='commons')

params = ParamDict()
params['cal_year'] = cal_year
results = qlambda.execute(parameters=params)
print(" ")
print("Largest Producers of Most Popular Genre in " + str(cal_year))
pp.pprint(results["results"])
print(" ")
# Out:
#
# Largest Producers of Most Popular Genre in 2001
# [{'Movie Count': 163, 'Popular Genre': 'Drama', 'Production Company': 'Warner Bros.', 'rank': 1},
# {'Movie Count': 143, 'Popular Genre': 'Drama', 'Production Company': 'Paramount Pictures', 'rank': 2},
# {'Movie Count': 127, 'Popular Genre': 'Drama', 'Production Company': 'Universal Pictures', 'rank': 3},
# {'Movie Count': 113, 'Popular Genre': 'Drama', 'Production Company': 'Twentieth Century Fox Film Corporation', 'rank': 4},
# {'Movie Count': 92, 'Popular Genre': 'Drama', 'Production Company': 'Metro-Goldwyn-Mayer (MGM)', 'rank': 5},
# {'Movie Count': 57, 'Popular Genre': 'Drama', 'Production Company': 'United Artists', 'rank': 6},
# {'Movie Count': 55, 'Popular Genre': 'Drama', 'Production Company': 'Columbia Pictures Corporation', 'rank': 7},
# {'Movie Count': 51, 'Popular Genre': 'Drama', 'Production Company': 'Canal+', 'rank': 8},
# {'Movie Count': 49, 'Popular Genre': 'Drama', 'Production Company': 'Columbia Pictures', 'rank': 9},
# {'Movie Count': 48, 'Popular Genre': 'Drama', 'Production Company': 'New Line Cinema', 'rank': 10}]

# %%
index = 0
x=[]
y=[]
for i in results["results"]:
    x.append(results["results"][index]["Production Company"])
    y.append(results["results"][index]["Movie Count"])
    index = index + 1
    
def valuelabel(x,y):
    for i in range(len(x)):
        plt.text(i,y[i],y[i], ha = 'center',
                 bbox = dict(facecolor = 'white', alpha =0.8))
        
plt.title("Largest Producers of " + results["results"][0]["Popular Genre"])
valuelabel(x,y)
plt.xlabel("Production Company")
plt.ylabel("Movie Count")
plt.xticks(rotation='vertical')
plt.bar(x,y)
plt.show()
